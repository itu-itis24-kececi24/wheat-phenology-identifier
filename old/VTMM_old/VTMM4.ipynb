# %% [markdown]
# ## VTMM4 — Tek rastgele 448 kırpma + **ardışık 2 günlük** softmax geçişi
#
# VTMM3 ile aynı **Dual ViT + tek random crop** eğitim hattı; **test doğruluğu** için tahminler doğrudan argmax yerine şu kurala göre çözümlenir:
#
# - İstasyon-yıl için günlük ortalama softmax **P** alınır.
# - Geçiş **PS_k → PS_{k+1}**: takvimde **ardışık iki gün** d ve d+1 (verisi olan) seçilir; **her iki günde** P(PS_{k+1}) > P(PS_k). **Tarih** olarak geçişin **ilk günü** d kullanılır; sonraki geçiş araması bu çiftten sonra devam eder (`vtmm4_decode`).
#
# - Çıktılar: **`vtmm4/`**
# - **CAPS:** donma / çözme ve erken durdurma VTMM3 ile uyumlu; iyileştirme metriği **sıralı çözüm doğruluğu**.
#
# Yolları kendi ortamınıza göre güncelleyin.

# %%
# --- LIBRARIES ---
import os
import random

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

import pandas as pd
import numpy as np
import re
from PIL import Image
from IPython.display import display

from framework import WheatFramework, generate_group_folds, save_model, run_fold_with_trainer

from vtmm4_decode import decode_labels_for_dataframe, sequential_decode_accuracy

# %%
# Update paths if different on your machine
excel_path = r".\labeling.xlsx"
data_path = r".\data"

# %%
wf = WheatFramework(excel_path=excel_path, root_dir=data_path)

try:
    meta_df = wf.get_dataframe()
except Exception as e:
    print("Error loading data:", e)
    meta_df = pd.DataFrame()

if not meta_df.empty:
    X, y, folds = wf.get_splits(meta_df, n_splits=5)
    print(f"Total matched images: {len(X)}")

    classes = list(wf.le.classes_)
    mapping = {i: cls for i, cls in enumerate(classes)}
    print("\nLabel mapping (encoded -> label):")
    for k, v in mapping.items():
        print(k, ":", v)

    print("\nSample matched paths and labels:")
    display(meta_df[["path", "label"]].head(8))

    wf.get_sample(X, y)
else:
    print("No images matched. Review previous prints above for column mapping and search path.")
# Out:
# Searching for images in: c:\Users\PC\Desktop\AI_TARBIL\code\data
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_01-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_02-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_03-10_11-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_05-10_11-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_06-10_12-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_07-09_53-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_08-09_54-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_09-09_52-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_10-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_11-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_12-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_13-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_14-10_12-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_15-10_12-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_16-10_01-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_17-10_01-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_18-10_03-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_19-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_20-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_21-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_22-10_05-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_23-10_07-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_24-10_07-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_25-10_06-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_26-10_08-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_29-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_30-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_01_31-10_03-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-01-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_01-09_46-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_02-09_49-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_03-09_47-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_04-09_46-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_07-09_49-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_11-09_50-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_12-09_48-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_13-09_49-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_14-09_49-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_15-09_48-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_16-09_50-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_17-09_53-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_18-09_55-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_19-09_56-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_20-09_54-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_21-09_56-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_23-09_53-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_24-09_53-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_25-09_55-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_26-09_55-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_27-09_55-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_02_28-09_56-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-02-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_01-09_57-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_02-09_55-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_03-09_57-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_04-09_57-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_05-09_47-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_06-09_47-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_07-10_13-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_08-10_01-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_09-10_01-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_10-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_11-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_12-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_13-10_04-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_14-10_07-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_15-10_07-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_23-10_09-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_24-10_13-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_26-10_11-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_29-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_30-10_10-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_03_31-09_49-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-03-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_01-09_58-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_04-10_01-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_05-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_06-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_07-10_03-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_09-09_54-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_10-10_13-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_11-10_15-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_12-10_14-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_13-10_15-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_14-10_13-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_15-10_16-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_16-10_16-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_26-08_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_04_30-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-04-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_05_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-05-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_06_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-06-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_07_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-07-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_04-11_12-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_12-09_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_08_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-08-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_12-11_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_17-10_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_09_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-09-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_02-09_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_08-11_12-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_10_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-10-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_11_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-11-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_25-10_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_26-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_27-10_02-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_28-10_03-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_29-10_05-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2014\K1\1X\02_02-2014_12_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2014-12-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_06-11_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\2015\K1\1X\02_02-2015_01_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2015-01-20
# ...
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_03_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-03-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_03_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-03-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_03_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-03-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_03_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-03-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_09-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_04_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-04-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_20-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_05_31-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-05-31
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-08
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_09-10_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-09
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_10-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-10
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_11-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-11
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_12-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-12
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_13-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-13
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_14-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-14
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_15-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-15
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_16-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-16
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_17-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-17
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_18-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-18
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_19-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-19
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_20-09_30-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-20
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_21-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-21
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_22-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-22
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_23-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-23
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_24-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-24
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_25-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-25
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_26-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-26
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_27-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-27
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_28-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-28
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_29-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-29
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_06_30-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-06-30
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_01-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-01
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_02-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-02
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_03-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-03
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_04-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-04
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_05-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-05
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_06-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-06
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_07-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-07
# Found image: c:\Users\PC\Desktop\AI_TARBIL\code\data\11.03\2017\K1\1X\11_03-2017_07_08-10_00-K1-1X.jpeg (matched date in filename) -   Parsed date 1: 2017-07-08
# Station folder not found for Excel value '1.01' (tried variants).
# Station folder not found for Excel value '1.05' (tried variants).
# Station folder not found for Excel value '26.11' (tried variants).
# Station folder not found for Excel value '26.12' (tried variants).
# Station folder not found for Excel value '27.02' (tried variants).
# Station folder not found for Excel value '27.03' (tried variants).
# Station folder not found for Excel value '27.04' (tried variants).
# Station folder not found for Excel value '27.05' (tried variants).
# Success! Matched 1742 images.
# Total matched images: 1742
#
# Label mapping (encoded -> label):
# 0 : PS0
# 1 : PS1
# 2 : PS2
# 3 : PS3
# 4 : PS4
# 5 : PS5
# 6 : PS6
# 7 : PS7
#
# Sample matched paths and labels:
#                                                 path label
# 0  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 1  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 2  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 3  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 4  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 5  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 6  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0
# 7  c:\Users\PC\Desktop\AI_TARBIL\code\data\02.02\...   PS0

# %%
# --- VTMM4: DUAL ViT — ONE RANDOM 448 CROP + SEQUENTIAL 2-DAY DECODE ---

TURKEY_COORDS = {
    1: (37.00, 35.32), 2: (37.76, 38.27), 3: (38.75, 30.55), 4: (39.71, 43.05), 5: (40.65, 35.83),
    6: (39.93, 32.85), 7: (36.89, 30.71), 8: (41.18, 41.81), 9: (37.84, 27.84), 10: (39.64, 27.88),
    11: (40.14, 29.97), 12: (38.88, 40.49), 13: (38.39, 42.10), 14: (40.73, 31.60), 15: (37.71, 30.28),
    16: (40.18, 29.06), 17: (40.15, 26.40), 18: (40.60, 33.61), 19: (40.54, 34.95), 20: (37.77, 29.08),
    21: (37.91, 40.23), 22: (41.67, 26.55), 23: (38.68, 39.22), 24: (39.74, 39.49), 25: (39.90, 41.27),
    26: (39.77, 30.52), 27: (37.06, 37.38), 28: (40.91, 38.38), 29: (40.45, 39.48), 30: (37.57, 43.73),
    31: (36.20, 36.15), 32: (37.76, 30.55), 33: (36.81, 34.64), 34: (41.00, 28.97), 35: (38.41, 27.14),
    36: (40.60, 43.09), 37: (41.37, 33.77), 38: (38.73, 35.48), 39: (41.73, 27.22), 40: (39.14, 34.16),
    41: (40.85, 29.88), 42: (37.87, 32.48), 43: (39.41, 29.98), 44: (38.35, 38.33), 45: (38.61, 27.42),
    46: (37.57, 36.92), 47: (37.31, 40.73), 48: (37.21, 28.36), 49: (38.73, 41.49), 50: (38.62, 34.71),
    51: (37.96, 34.67), 52: (40.98, 37.87), 53: (41.02, 40.51), 54: (40.77, 30.39), 55: (41.28, 36.33),
    56: (37.92, 41.94), 57: (42.02, 35.15), 58: (39.74, 37.01), 59: (40.97, 27.51), 60: (40.32, 36.55),
    61: (41.00, 39.71), 62: (39.10, 39.54), 63: (37.16, 38.79), 64: (38.67, 29.40), 65: (38.50, 43.37),
    66: (39.82, 34.80), 67: (41.45, 31.78), 68: (38.36, 34.02), 69: (40.26, 40.22), 70: (37.18, 33.21),
    71: (39.84, 33.51), 72: (37.88, 41.12), 73: (37.51, 42.45), 74: (41.63, 32.33), 75: (41.11, 42.70),
    76: (39.92, 44.04), 77: (40.65, 29.27), 78: (41.19, 32.62), 79: (36.71, 37.11), 80: (37.07, 36.24),
    81: (40.84, 31.15),
}
DEFAULT_COORD = (39.93, 32.85)


def prepare_advanced_features(df):
    df = df.copy()

    def extract_date(path):
        match = re.search(r"(\d{4}[_-]\d{2}[_-]\d{2})", str(path))
        if not match:
            return pd.NaT
        return pd.to_datetime(match.group(1).replace("-", "_"), format="%Y_%m_%d", errors="coerce")

    df["dt"] = df["path"].apply(extract_date)

    def get_agricultural_doy(date):
        if pd.isna(date):
            return np.nan
        planting_year = date.year if date.month >= 11 else date.year - 1
        nov_1st = pd.Timestamp(year=planting_year, month=11, day=1)
        return (date - nov_1st).days + 1

    df["agri_day_of_year"] = df["dt"].apply(get_agricultural_doy)
    df["date_missing"] = df["dt"].isna().astype(np.float32)
    df["plate_code"] = df["station_year"].astype(str).str.extract(r"^(\d{2})")[0].astype(float)

    def get_lat_lon(plate):
        if pd.isna(plate) or int(plate) not in TURKEY_COORDS:
            return DEFAULT_COORD
        return TURKEY_COORDS[int(plate)]

    coords = df["plate_code"].apply(get_lat_lon)
    df["latitude"] = [c[0] for c in coords]
    df["longitude"] = [c[1] for c in coords]
    return df


def _ensure_min_side(img: Image.Image, min_side: int) -> Image.Image:
    w, h = img.size
    if min(w, h) >= min_side:
        return img
    scale = min_side / min(w, h)
    nw, nh = max(int(round(w * scale)), min_side), max(int(round(h * scale)), min_side)
    return img.resize((nw, nh), Image.BICUBIC)


def _random_square_crop_pil(img: Image.Image, crop_size: int) -> Image.Image:
    img = _ensure_min_side(img, crop_size)
    w, h = img.size
    left = random.randint(0, w - crop_size)
    top = random.randint(0, h - crop_size)
    return img.crop((left, top, left + crop_size, top + crop_size))


class MultimodalSingleCropDataset(Dataset):
    # One random 448×448 crop per sample (not four quadrants / four draws).

    def __init__(self, df, label_map, crop_size, train_transform, eval_transform, is_training=True):
        self.df = df.reset_index(drop=True)
        self.label_map = label_map
        self.crop_size = int(crop_size)
        self.train_transform = train_transform
        self.eval_transform = eval_transform
        self.is_training = is_training

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row["path"]).convert("RGB")
        patch = _random_square_crop_pil(img, self.crop_size)

        if self.is_training:
            if self.train_transform:
                patch = self.train_transform(patch)
        else:
            if self.eval_transform:
                patch = self.eval_transform(patch)
        img_data = patch

        agri_day = row["agri_day_of_year"]
        lat_norm = row["latitude"]
        lon_norm = row["longitude"]
        meta_tensor = torch.tensor([agri_day, lat_norm, lon_norm], dtype=torch.float32)
        label_tensor = torch.tensor(self.label_map[row["label"]], dtype=torch.long)
        return img_data, meta_tensor, label_tensor


class MultimodalViTDual(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        from torchvision.models.vision_transformer import interpolate_embeddings

        weights = models.ViT_B_16_Weights.DEFAULT
        vit_num = 2
        self.vit_arr = nn.ModuleList([models.vit_b_16(weights=None, image_size=448) for _ in range(vit_num)])
        state_dict = weights.get_state_dict(progress=True)
        state_dict = interpolate_embeddings(
            image_size=448, patch_size=16, model_state=state_dict, reset_heads=True
        )
        vit_dim = self.vit_arr[0].heads.head.in_features
        for vit in self.vit_arr:
            vit.load_state_dict(state_dict, strict=False)
            vit.heads = nn.Identity()
        self.meta_net = nn.Sequential(
            nn.Linear(3, 64),
            nn.GELU(),
            nn.Dropout(0.25),
            nn.Linear(64, 128),
            nn.GELU(),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(0.38),
            nn.Linear(vit_num * vit_dim + 128, 256),
            nn.GELU(),
            nn.Dropout(0.28),
            nn.Linear(256, 256),
            nn.GELU(),
            nn.Dropout(0.25),
            nn.Linear(256, num_classes),
        )

    def forward(self, img, meta):
        v_features = torch.cat([vit(img) for vit in self.vit_arr], dim=1)
        m_features = self.meta_net(meta)
        combined = torch.cat((v_features, m_features), dim=1)
        return self.classifier(combined)


def _dual_vit_backbone_params(model):
    ps = []
    for vit in model.vit_arr:
        ps += list(vit.parameters())
    return ps


def _dual_vit_head_params(model):
    return list(model.meta_net.parameters()) + list(model.classifier.parameters())


VTMM4_OUT = "vtmm4"
os.makedirs(VTMM4_OUT, exist_ok=True)


def multimodal_single_crop_trainer(train_df, test_df, fold_id, config):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    img_size = config.get("img_size", 448)
    freeze_epochs = int(config.get("freeze_epochs", 2))
    base_lr = config["lr"]
    weight_decay = config.get("weight_decay", 0.08)
    label_smoothing = config.get("label_smoothing", 0.08)
    max_grad_norm = float(config.get("max_grad_norm", 1.0))
    unfreeze_lr_mult = float(config.get("unfreeze_lr_mult", 0.5))
    heads_lr_boost = float(config.get("heads_lr_boost", 2.0))

    all_labels = sorted(train_df["label"].unique())
    label_map = {label: i for i, label in enumerate(all_labels)}
    inv_map = {v: k for k, v in label_map.items()}
    num_classes = len(all_labels)

    for df_ in [train_df, test_df]:
        df_["latitude"] = df_["latitude"].fillna(39.93)
        df_["longitude"] = df_["longitude"].fillna(32.85)
        df_["latitude"] = (df_["latitude"] - 36.20) / (41.73 - 36.20)
        df_["longitude"] = (df_["longitude"] - 26.39) / (43.73 - 26.39)

    train_transform = transforms.Compose(
        [
            transforms.RandomHorizontalFlip(),
            transforms.RandomApply(
                [transforms.ColorJitter(brightness=0.15, contrast=0.15, saturation=0.15, hue=0.04)], p=0.55
            ),
            transforms.RandomApply([transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 0.35))], p=0.12),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    )

    eval_transform = transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    )

    train_ds = MultimodalSingleCropDataset(
        train_df, label_map, img_size, train_transform, eval_transform, is_training=True
    )
    test_ds = MultimodalSingleCropDataset(
        test_df, label_map, img_size, train_transform, eval_transform, is_training=False
    )

    bs = config["batch_size"]
    train_loader = DataLoader(train_ds, batch_size=bs, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=bs, shuffle=False)

    model = MultimodalViTDual(num_classes).to(device)

    for p in _dual_vit_backbone_params(model):
        p.requires_grad = False

    backbone = _dual_vit_backbone_params(model)
    heads = _dual_vit_head_params(model)

    criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
    epochs = config["epochs"]

    eta_min_head = base_lr * heads_lr_boost * 0.05
    if freeze_epochs <= 0:
        for p in backbone:
            p.requires_grad = True
        lr_full = base_lr * unfreeze_lr_mult
        optimizer = optim.AdamW(model.parameters(), lr=lr_full, weight_decay=weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=max(1, epochs), eta_min=max(lr_full * 0.02, base_lr * 1e-4)
        )
    else:
        optimizer = optim.AdamW(heads, lr=base_lr * heads_lr_boost, weight_decay=weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=max(1, freeze_epochs), eta_min=eta_min_head
        )

    best_acc = 0.0
    best_pred_df = None
    best_model_state = None
    acc_not_increased_epoch_num = 0

    print(f"\n{'='*40}")
    print(
        f"[VTMM4 DUAL ViT] FOLD {fold_id} · one random {img_size}px crop | "
        "test metric: sequential 2-day P decode"
    )
    print(f"{'='*40}")

    for epoch in range(epochs):
        if freeze_epochs > 0 and epoch == freeze_epochs:
            lr_full = base_lr * unfreeze_lr_mult
            print(f"CAPS FREEZE PHASE END epoch={epoch}: UNFREEZE ViT, NEW OPTIM LR={lr_full}")
            for p in backbone:
                p.requires_grad = True
            optimizer = optim.AdamW(model.parameters(), lr=lr_full, weight_decay=weight_decay)
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer,
                T_max=max(1, epochs - freeze_epochs),
                eta_min=max(lr_full * 0.02, base_lr * 1e-4),
            )

        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for imgs, metas, lbls in train_loader:
            metas = metas.to(device)
            lbls = lbls.to(device)
            imgs = imgs.to(device)
            optimizer.zero_grad()
            outputs = model(imgs, metas)
            loss = criterion(outputs, lbls)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += lbls.size(0)
            correct += predicted.eq(lbls).sum().item()

        scheduler.step()

        model.eval()
        all_probs_batches = []
        with torch.no_grad():
            for imgs, metas, lbls in test_loader:
                imgs = imgs.to(device)
                metas = metas.to(device)
                lbls = lbls.to(device)
                out = model(imgs, metas)
                all_probs_batches.append(torch.softmax(out, dim=1).cpu().numpy())

        probs_arr = np.concatenate(all_probs_batches, axis=0)
        test_eval_df = test_df.reset_index(drop=True)
        class_names_seq = [inv_map[i] for i in range(num_classes)]
        fold_acc = sequential_decode_accuracy(
            test_eval_df,
            probs_arr,
            class_names_seq,
            true_col="label",
            date_col="dt",
            group_col="station_year",
        )
        decode_pred = decode_labels_for_dataframe(
            test_eval_df,
            probs_arr,
            class_names_seq,
            date_col="dt",
            group_col="station_year",
        )
        y_true_str = test_eval_df["label"].astype(str).values
        y_pred_str = decode_pred.astype(str).values

        print(
            f"[VTMM4 dual] Epoch {epoch+1} train Loss: {running_loss / max(len(train_loader), 1):.4f} "
            f"| train Acc: {100.0 * correct / max(total, 1):.2f}% | test seq-dec Acc: {fold_acc:.4f}"
        )

        import matplotlib.pyplot as plt
        import seaborn as sns

        plt.figure(figsize=(6, 5))
        sns.heatmap(
            pd.crosstab(pd.Series(y_true_str, name="True"), pd.Series(y_pred_str, name="Pred")),
            annot=True,
            fmt="d",
            cmap="Blues",
        )
        plt.title(f"[VTMM4 dual seq-dec] Fold {fold_id} epoch {epoch+1}")
        plt.tight_layout()
        plt.savefig(os.path.join(VTMM4_OUT, f"fold_{fold_id}_dual_epoch_{epoch+1}_confusion_matrix.png"))
        plt.close()

        if fold_acc <= best_acc:
            acc_not_increased_epoch_num += 1
        else:
            acc_not_increased_epoch_num = 0
            best_acc = fold_acc
            print(f"  New best seq-dec acc {best_acc:.4f}")
            best_model_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            best_pred_df = pd.DataFrame(
                {
                    "path": test_eval_df["path"].values,
                    "true": y_true_str,
                    "pred": y_pred_str,
                }
            )

            model.load_state_dict(best_model_state)
            if best_acc >= float(config.get("save_acc_threshold", 0.70)):
                save_path = os.path.join(VTMM4_OUT, f"fold_{fold_id}_dual_acc{best_acc:.4f}.pth")
                save_model(model, save_path)
                print(f"  CAPS SAVED MODEL (TEST ACC >= threshold): {save_path}")
            model.train()

        if acc_not_increased_epoch_num > 0:
            print(f"  No test improvement for {acc_not_increased_epoch_num} epoch(s)")
        else:
            print("  Accuracy improved — reset patience")

        pat = config.get("patience", 3)
        if acc_not_increased_epoch_num >= pat:
            print(f"CAPS EARLY STOP: no gain {pat} epochs.")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    print(f"[VTMM4 dual] FOLD {fold_id} BEST TEST SEQ-DEC ACCURACY: {best_acc:.4f}\n")
    return {"model": model, "predictions": best_pred_df, "metrics": {"accuracy": best_acc}}


multi_config = {
    "img_size": 448,
    "batch_size": 4,
    "lr": 1e-5,
    "epochs": 48,
    "weight_decay": 0.085,
    "label_smoothing": 0.08,
    "max_grad_norm": 1.0,
    "freeze_epochs": 2,
    "unfreeze_lr_mult": 0.45,
    "heads_lr_boost": 2.0,
    "save_acc_threshold": 0.70,
    "patience": 12,
}

meta_df_advanced = prepare_advanced_features(meta_df)

folds = generate_group_folds(
    meta_df_advanced, n_train=8, n_test=2, num_folds=5, group_col="group_id", random_state=42
)
multi_metrics = []

for f_idx, (tr_idx, te_idx) in enumerate(folds):
    result = run_fold_with_trainer(
        meta_df=meta_df_advanced,
        train_idx=tr_idx,
        test_idx=te_idx,
        trainer_fn=lambda tr, te, fid: multimodal_single_crop_trainer(tr, te, fid, multi_config),
        fold_id=f_idx + 1,
    )
    multi_metrics.append(result["metrics"]["accuracy"])

print("\n--- VTMM4 DUAL FINAL MEAN SEQ-DEC ACC ---")
print(np.mean(multi_metrics))
# Out:
# c:\Users\PC\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1355: UserWarning: expandable_segments not supported on this platform (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\c10/cuda/CUDAAllocatorConfig.h:35.)
#   return t.to(
# ========================================
# [VTMM4 DUAL ViT] FOLD 1 · one random 448px crop | test metric: sequential 2-day P decode
# ========================================
# [VTMM4 dual] Epoch 1 train Loss: 2.1555 | train Acc: 16.83% | test seq-dec Acc: 0.2782
#   New best seq-dec acc 0.2782
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 2 train Loss: 2.0103 | train Acc: 24.98% | test seq-dec Acc: 0.3465
#   New best seq-dec acc 0.3465
#   Accuracy improved — reset patience
# CAPS FREEZE PHASE END epoch=2: UNFREEZE ViT, NEW OPTIM LR=4.5e-06
# [VTMM4 dual] Epoch 3 train Loss: 1.7935 | train Acc: 36.81% | test seq-dec Acc: 0.2415
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 4 train Loss: 1.5640 | train Acc: 48.27% | test seq-dec Acc: 0.2703
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 5 train Loss: 1.3926 | train Acc: 57.53% | test seq-dec Acc: 0.2283
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 6 train Loss: 1.2419 | train Acc: 63.63% | test seq-dec Acc: 0.1864
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 7 train Loss: 1.1537 | train Acc: 67.30% | test seq-dec Acc: 0.2178
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 8 train Loss: 1.0929 | train Acc: 69.80% | test seq-dec Acc: 0.2126
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 9 train Loss: 1.0329 | train Acc: 71.71% | test seq-dec Acc: 0.2625
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 10 train Loss: 0.9566 | train Acc: 74.94% | test seq-dec Acc: 0.2493
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 11 train Loss: 0.9279 | train Acc: 77.22% | test seq-dec Acc: 0.2808
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 12 train Loss: 0.8880 | train Acc: 79.65% | test seq-dec Acc: 0.2100
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 13 train Loss: 0.8448 | train Acc: 80.68% | test seq-dec Acc: 0.2572
#   No test improvement for 11 epoch(s)
# [VTMM4 dual] Epoch 14 train Loss: 0.8379 | train Acc: 81.63% | test seq-dec Acc: 0.2782
#   No test improvement for 12 epoch(s)
# CAPS EARLY STOP: no gain 12 epochs.
# [VTMM4 dual] FOLD 1 BEST TEST SEQ-DEC ACCURACY: 0.3465
#
#
# ========================================
# [VTMM4 DUAL ViT] FOLD 2 · one random 448px crop | test metric: sequential 2-day P decode
# ========================================
# [VTMM4 dual] Epoch 1 train Loss: 2.1142 | train Acc: 23.41% | test seq-dec Acc: 0.3343
#   New best seq-dec acc 0.3343
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 2 train Loss: 1.9828 | train Acc: 31.23% | test seq-dec Acc: 0.4475
#   New best seq-dec acc 0.4475
#   Accuracy improved — reset patience
# CAPS FREEZE PHASE END epoch=2: UNFREEZE ViT, NEW OPTIM LR=4.5e-06
# [VTMM4 dual] Epoch 3 train Loss: 1.7482 | train Acc: 41.88% | test seq-dec Acc: 0.2818
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 4 train Loss: 1.5627 | train Acc: 48.55% | test seq-dec Acc: 0.1878
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 5 train Loss: 1.3995 | train Acc: 57.83% | test seq-dec Acc: 0.2597
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 6 train Loss: 1.2604 | train Acc: 64.20% | test seq-dec Acc: 0.3011
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 7 train Loss: 1.1582 | train Acc: 68.55% | test seq-dec Acc: 0.2320
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 8 train Loss: 1.0520 | train Acc: 73.04% | test seq-dec Acc: 0.1878
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 9 train Loss: 0.9991 | train Acc: 74.78% | test seq-dec Acc: 0.2624
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 10 train Loss: 0.9586 | train Acc: 76.38% | test seq-dec Acc: 0.2790
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 11 train Loss: 0.9118 | train Acc: 77.03% | test seq-dec Acc: 0.2845
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 12 train Loss: 0.8630 | train Acc: 80.07% | test seq-dec Acc: 0.2486
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 13 train Loss: 0.8382 | train Acc: 82.97% | test seq-dec Acc: 0.1271
#   No test improvement for 11 epoch(s)
# [VTMM4 dual] Epoch 14 train Loss: 0.8045 | train Acc: 83.12% | test seq-dec Acc: 0.2569
#   No test improvement for 12 epoch(s)
# CAPS EARLY STOP: no gain 12 epochs.
# [VTMM4 dual] FOLD 2 BEST TEST SEQ-DEC ACCURACY: 0.4475
#
#
# ========================================
# [VTMM4 DUAL ViT] FOLD 3 · one random 448px crop | test metric: sequential 2-day P decode
# ========================================
# [VTMM4 dual] Epoch 1 train Loss: 2.1609 | train Acc: 21.70% | test seq-dec Acc: 0.2197
#   New best seq-dec acc 0.2197
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 2 train Loss: 2.0462 | train Acc: 30.06% | test seq-dec Acc: 0.1521
#   No test improvement for 1 epoch(s)
# CAPS FREEZE PHASE END epoch=2: UNFREEZE ViT, NEW OPTIM LR=4.5e-06
# [VTMM4 dual] Epoch 3 train Loss: 1.8719 | train Acc: 38.00% | test seq-dec Acc: 0.3803
#   New best seq-dec acc 0.3803
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 4 train Loss: 1.6345 | train Acc: 46.79% | test seq-dec Acc: 0.5380
#   New best seq-dec acc 0.5380
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 5 train Loss: 1.4854 | train Acc: 54.00% | test seq-dec Acc: 0.4479
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 6 train Loss: 1.3352 | train Acc: 59.99% | test seq-dec Acc: 0.4592
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 7 train Loss: 1.2806 | train Acc: 62.73% | test seq-dec Acc: 0.3718
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 8 train Loss: 1.1998 | train Acc: 65.39% | test seq-dec Acc: 0.6451
#   New best seq-dec acc 0.6451
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 9 train Loss: 1.1035 | train Acc: 68.93% | test seq-dec Acc: 0.6507
#   New best seq-dec acc 0.6507
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 10 train Loss: 1.0830 | train Acc: 70.37% | test seq-dec Acc: 0.4930
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 11 train Loss: 1.0253 | train Acc: 73.68% | test seq-dec Acc: 0.6169
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 12 train Loss: 0.9663 | train Acc: 75.41% | test seq-dec Acc: 0.4676
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 13 train Loss: 0.9274 | train Acc: 78.37% | test seq-dec Acc: 0.6676
#   New best seq-dec acc 0.6676
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 14 train Loss: 0.9375 | train Acc: 76.86% | test seq-dec Acc: 0.7070
#   New best seq-dec acc 0.7070
#   CAPS SAVED MODEL (TEST ACC >= threshold): vtmm4\fold_3_dual_acc0.7070.pth
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 15 train Loss: 0.8547 | train Acc: 81.18% | test seq-dec Acc: 0.7493
#   New best seq-dec acc 0.7493
#   CAPS SAVED MODEL (TEST ACC >= threshold): vtmm4\fold_3_dual_acc0.7493.pth
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 16 train Loss: 0.8714 | train Acc: 80.46% | test seq-dec Acc: 0.6113
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 17 train Loss: 0.8585 | train Acc: 81.90% | test seq-dec Acc: 0.5324
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 18 train Loss: 0.8060 | train Acc: 83.20% | test seq-dec Acc: 0.6535
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 19 train Loss: 0.8299 | train Acc: 82.62% | test seq-dec Acc: 0.6676
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 20 train Loss: 0.7691 | train Acc: 85.00% | test seq-dec Acc: 0.4394
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 21 train Loss: 0.7621 | train Acc: 85.36% | test seq-dec Acc: 0.5014
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 22 train Loss: 0.7542 | train Acc: 87.74% | test seq-dec Acc: 0.6930
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 23 train Loss: 0.7502 | train Acc: 85.94% | test seq-dec Acc: 0.5662
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 24 train Loss: 0.7265 | train Acc: 87.82% | test seq-dec Acc: 0.5239
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 25 train Loss: 0.7190 | train Acc: 87.96% | test seq-dec Acc: 0.5662
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 26 train Loss: 0.7104 | train Acc: 88.82% | test seq-dec Acc: 0.5465
#   No test improvement for 11 epoch(s)
# [VTMM4 dual] Epoch 27 train Loss: 0.7128 | train Acc: 88.25% | test seq-dec Acc: 0.5042
#   No test improvement for 12 epoch(s)
# CAPS EARLY STOP: no gain 12 epochs.
# [VTMM4 dual] FOLD 3 BEST TEST SEQ-DEC ACCURACY: 0.7493
#
#
# ========================================
# [VTMM4 DUAL ViT] FOLD 4 · one random 448px crop | test metric: sequential 2-day P decode
# ========================================
# [VTMM4 dual] Epoch 1 train Loss: 2.1573 | train Acc: 22.19% | test seq-dec Acc: 0.1518
#   New best seq-dec acc 0.1518
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 2 train Loss: 1.9992 | train Acc: 33.29% | test seq-dec Acc: 0.1220
#   No test improvement for 1 epoch(s)
# CAPS FREEZE PHASE END epoch=2: UNFREEZE ViT, NEW OPTIM LR=4.5e-06
# [VTMM4 dual] Epoch 3 train Loss: 1.8382 | train Acc: 37.41% | test seq-dec Acc: 0.3036
#   New best seq-dec acc 0.3036
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 4 train Loss: 1.6607 | train Acc: 45.52% | test seq-dec Acc: 0.3958
#   New best seq-dec acc 0.3958
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 5 train Loss: 1.4665 | train Acc: 53.56% | test seq-dec Acc: 0.4226
#   New best seq-dec acc 0.4226
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 6 train Loss: 1.3444 | train Acc: 58.68% | test seq-dec Acc: 0.6071
#   New best seq-dec acc 0.6071
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 7 train Loss: 1.2465 | train Acc: 63.02% | test seq-dec Acc: 0.6161
#   New best seq-dec acc 0.6161
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 8 train Loss: 1.1477 | train Acc: 68.14% | test seq-dec Acc: 0.6964
#   New best seq-dec acc 0.6964
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 9 train Loss: 1.0973 | train Acc: 70.13% | test seq-dec Acc: 0.7530
#   New best seq-dec acc 0.7530
#   CAPS SAVED MODEL (TEST ACC >= threshold): vtmm4\fold_4_dual_acc0.7530.pth
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 10 train Loss: 1.0003 | train Acc: 75.11% | test seq-dec Acc: 0.6815
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 11 train Loss: 1.0090 | train Acc: 74.04% | test seq-dec Acc: 0.7411
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 12 train Loss: 0.9538 | train Acc: 75.32% | test seq-dec Acc: 0.7887
#   New best seq-dec acc 0.7887
#   CAPS SAVED MODEL (TEST ACC >= threshold): vtmm4\fold_4_dual_acc0.7887.pth
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 13 train Loss: 0.9477 | train Acc: 77.31% | test seq-dec Acc: 0.6964
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 14 train Loss: 0.8770 | train Acc: 79.30% | test seq-dec Acc: 0.6190
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 15 train Loss: 0.8733 | train Acc: 80.16% | test seq-dec Acc: 0.7470
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 16 train Loss: 0.8604 | train Acc: 80.37% | test seq-dec Acc: 0.6726
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 17 train Loss: 0.8205 | train Acc: 81.93% | test seq-dec Acc: 0.6845
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 18 train Loss: 0.8094 | train Acc: 81.72% | test seq-dec Acc: 0.6310
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 19 train Loss: 0.7816 | train Acc: 84.28% | test seq-dec Acc: 0.6369
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 20 train Loss: 0.7747 | train Acc: 83.93% | test seq-dec Acc: 0.7292
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 21 train Loss: 0.7894 | train Acc: 84.14% | test seq-dec Acc: 0.7173
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 22 train Loss: 0.7439 | train Acc: 86.42% | test seq-dec Acc: 0.6905
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 23 train Loss: 0.7612 | train Acc: 86.56% | test seq-dec Acc: 0.6667
#   No test improvement for 11 epoch(s)
# [VTMM4 dual] Epoch 24 train Loss: 0.7510 | train Acc: 86.49% | test seq-dec Acc: 0.6994
#   No test improvement for 12 epoch(s)
# CAPS EARLY STOP: no gain 12 epochs.
# [VTMM4 dual] FOLD 4 BEST TEST SEQ-DEC ACCURACY: 0.7887
#
#
# ========================================
# [VTMM4 DUAL ViT] FOLD 5 · one random 448px crop | test metric: sequential 2-day P decode
# ========================================
# [VTMM4 dual] Epoch 1 train Loss: 2.0658 | train Acc: 22.78% | test seq-dec Acc: 0.3183
#   New best seq-dec acc 0.3183
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 2 train Loss: 1.9265 | train Acc: 32.80% | test seq-dec Acc: 0.3859
#   New best seq-dec acc 0.3859
#   Accuracy improved — reset patience
# CAPS FREEZE PHASE END epoch=2: UNFREEZE ViT, NEW OPTIM LR=4.5e-06
# [VTMM4 dual] Epoch 3 train Loss: 1.7333 | train Acc: 40.30% | test seq-dec Acc: 0.2366
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 4 train Loss: 1.5181 | train Acc: 49.10% | test seq-dec Acc: 0.3324
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 5 train Loss: 1.3432 | train Acc: 59.34% | test seq-dec Acc: 0.3718
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 6 train Loss: 1.2270 | train Acc: 65.54% | test seq-dec Acc: 0.3775
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 7 train Loss: 1.1283 | train Acc: 68.49% | test seq-dec Acc: 0.3746
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 8 train Loss: 1.0486 | train Acc: 72.31% | test seq-dec Acc: 0.4000
#   New best seq-dec acc 0.4000
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 9 train Loss: 1.0013 | train Acc: 73.32% | test seq-dec Acc: 0.4873
#   New best seq-dec acc 0.4873
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 10 train Loss: 0.9217 | train Acc: 78.44% | test seq-dec Acc: 0.4338
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 11 train Loss: 0.8895 | train Acc: 79.81% | test seq-dec Acc: 0.3465
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 12 train Loss: 0.8456 | train Acc: 81.40% | test seq-dec Acc: 0.3718
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 13 train Loss: 0.8180 | train Acc: 82.34% | test seq-dec Acc: 0.3859
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 14 train Loss: 0.8076 | train Acc: 82.34% | test seq-dec Acc: 0.3268
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 15 train Loss: 0.7933 | train Acc: 82.98% | test seq-dec Acc: 0.4056
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 16 train Loss: 0.7444 | train Acc: 86.16% | test seq-dec Acc: 0.4141
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 17 train Loss: 0.7510 | train Acc: 85.08% | test seq-dec Acc: 0.4366
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 18 train Loss: 0.7414 | train Acc: 86.16% | test seq-dec Acc: 0.4451
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 19 train Loss: 0.7203 | train Acc: 86.30% | test seq-dec Acc: 0.4423
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 20 train Loss: 0.7078 | train Acc: 88.03% | test seq-dec Acc: 0.5042
#   New best seq-dec acc 0.5042
#   Accuracy improved — reset patience
# [VTMM4 dual] Epoch 21 train Loss: 0.6995 | train Acc: 87.96% | test seq-dec Acc: 0.3746
#   No test improvement for 1 epoch(s)
# [VTMM4 dual] Epoch 22 train Loss: 0.6876 | train Acc: 88.46% | test seq-dec Acc: 0.2930
#   No test improvement for 2 epoch(s)
# [VTMM4 dual] Epoch 23 train Loss: 0.7231 | train Acc: 88.68% | test seq-dec Acc: 0.3380
#   No test improvement for 3 epoch(s)
# [VTMM4 dual] Epoch 24 train Loss: 0.6742 | train Acc: 89.98% | test seq-dec Acc: 0.3859
#   No test improvement for 4 epoch(s)
# [VTMM4 dual] Epoch 25 train Loss: 0.6525 | train Acc: 89.91% | test seq-dec Acc: 0.3239
#   No test improvement for 5 epoch(s)
# [VTMM4 dual] Epoch 26 train Loss: 0.6507 | train Acc: 91.20% | test seq-dec Acc: 0.3437
#   No test improvement for 6 epoch(s)
# [VTMM4 dual] Epoch 27 train Loss: 0.6606 | train Acc: 90.77% | test seq-dec Acc: 0.4113
#   No test improvement for 7 epoch(s)
# [VTMM4 dual] Epoch 28 train Loss: 0.6490 | train Acc: 90.48% | test seq-dec Acc: 0.3070
#   No test improvement for 8 epoch(s)
# [VTMM4 dual] Epoch 29 train Loss: 0.6698 | train Acc: 90.19% | test seq-dec Acc: 0.3690
#   No test improvement for 9 epoch(s)
# [VTMM4 dual] Epoch 30 train Loss: 0.6476 | train Acc: 90.99% | test seq-dec Acc: 0.4085
#   No test improvement for 10 epoch(s)
# [VTMM4 dual] Epoch 31 train Loss: 0.6403 | train Acc: 91.56% | test seq-dec Acc: 0.3662
#   No test improvement for 11 epoch(s)
# [VTMM4 dual] Epoch 32 train Loss: 0.6370 | train Acc: 91.71% | test seq-dec Acc: 0.3380
#   No test improvement for 12 epoch(s)
# CAPS EARLY STOP: no gain 12 epochs.
# [VTMM4 dual] FOLD 5 BEST TEST SEQ-DEC ACCURACY: 0.5042
#
#
# --- VTMM4 DUAL FINAL MEAN SEQ-DEC ACC ---
# 0.5672364216038244
